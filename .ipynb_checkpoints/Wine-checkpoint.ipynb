# %%
import pandas as pd
df = pd.read_csv("Wine_quality_red.csv")
df
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

#와인 데이터 읽어 들이기
wine = pd.read_csv("Wine_quality_red.csv", sep = ";", encoding = "utf-8")

#품질 데이터별로 그룹을 나누고 수 세어보기
count_data = wine.groupby('quality')["quality"].count()
print(count_data)

#수를 그래프로 그리기
count_data.plot()
plt.savefig("wine-count-plt.png")
plt.show()
# Out:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report 

#데이터 읽어 들이기
wine = pd.read_csv("Wine_quality_red.csv",sep =";", encoding="utf-8")

#데이터를 레이블과 데이터로 분리하기
y = wine["quality"]
x = wine.drop("quality", axis = 1)

#학습전용과 테스트 전용으로 분리하기
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

#학습하기
model = RandomForestClassifier()
model.fit(x_train, y_train)

#평가하기
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("정답률 = ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         9
#            5       0.77      0.81      0.79       137
#            6       0.71      0.77      0.74       138
#            7       0.50      0.39      0.44        31
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.72       320
#    macro avg       0.33      0.33      0.33       320
# weighted avg       0.68      0.72      0.70       320
#
# 정답률 =  0.715625
# C:\Users\user\anaconda\envs\test\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#오답표시
num = 0

predict = []
answer = []

for i in y_pred:
    predict.append(i)

for j in y_test:
    answer.append(j)
    
for k in predict:
    if(k != answer[num]):
        print("predict : ", k, ", answer : ", answer[num])
    num = num + 1

num = 0
# Out:
# predict :  5 , answer :  4
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  4 , answer :  3
# predict :  7 , answer :  8
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  7 , answer :  6
# predict :  5 , answer :  6
# predict :  6 , answer :  7
# predict :  7 , answer :  6
# predict :  6 , answer :  5
# predict :  5 , answer :  7
# predict :  5 , answer :  4
# predict :  6 , answer :  7
# predict :  6 , answer :  7
# predict :  5 , answer :  7
# predict :  5 , answer :  6
# predict :  7 , answer :  8
# predict :  5 , answer :  4
# predict :  7 , answer :  6
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  5 , answer :  6
# predict :  5 , answer :  4
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  6 , answer :  4
# predict :  6 , answer :  5
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  7 , answer :  6
# predict :  5 , answer :  6
# predict :  5 , answer :  7
# predict :  7 , answer :  6
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  6 , answer :  5
# predict :  4 , answer :  5
# predict :  6 , answer :  5
# predict :  7 , answer :  8
# predict :  6 , answer :  5
# predict :  6 , answer :  5
# predict :  6 , answer :  5
# predict :  6 , answer :  5
# predict :  7 , answer :  5
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  6 , answer :  4
# predict :  6 , answer :  5
# predict :  5 , answer :  4
# predict :  6 , answer :  5
# predict :  6 , answer :  4
# predict :  6 , answer :  5
# predict :  6 , answer :  7
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  6 , answer :  7
# predict :  6 , answer :  5
# predict :  6 , answer :  7
# predict :  6 , answer :  5
# predict :  6 , answer :  7
# predict :  5 , answer :  6
# predict :  6 , answer :  5
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  7 , answer :  6
# predict :  6 , answer :  7
# predict :  6 , answer :  7
# predict :  6 , answer :  5
# predict :  6 , answer :  7
# predict :  7 , answer :  6
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  6 , answer :  7
# predict :  6 , answer :  5
# predict :  5 , answer :  6
# predict :  5 , answer :  3
# predict :  5 , answer :  4
# predict :  5 , answer :  6
# predict :  7 , answer :  6
# predict :  6 , answer :  5
